# %%
def load_example_data():
    """Load an example CSV file from the raw data directory"""
    file_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
    return read_csv_file(file_path)

file = load_example_data()
file.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/src/data/make_dataset.py:6
#       3     file_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
#       4     return read_csv_file(file_path)
# ----> 6 file = load_example_data()
#       7 file.head()
#
# File /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/src/data/make_dataset.py:3
#       1 def load_example_data():
#       2     """Load an example CSV file from the raw data directory"""
# ----> 3     file_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
#       4     return read_csv_file(file_path)
#
# NameError: name 'ABSOLUTE_DATA_PATH' is not defined

# %%
import pandas as pd
from glob import glob

# --------------------------------------------------------------
# Read single CSV file
# --------------------------------------------------------------

def read_csv_file(file_path):
    """Read a CSV file from the data directory"""
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return None

# Example path structure (adjust according to your data location):
# Absolute path from project root
DATA_PATH = "data/raw/"  # This will be relative to where you run the notebook from

# You can also use this more robust path that works regardless of where you run from:
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.path.dirname(__file__), "../.."))
ABSOLUTE_DATA_PATH = os.path.join(PROJECT_ROOT, "data", "raw")

# Example usage with an actual file from your dataset:
EXAMPLE_FILE = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

def list_data_files():
    """List all CSV files in the raw data directory"""
    return glob(os.path.join(ABSOLUTE_DATA_PATH, '*.csv'))

def load_example_data():
    """Load an example CSV file from the raw data directory"""
    file_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
    return read_csv_file(file_path)

file = load_example_data()
file.head()
# Out:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547472169751  2019-01-14T14:22:49.751         0.00      -0.147
# 1  1547472169831  2019-01-14T14:22:49.831         0.08      -0.120
# 2  1547472169911  2019-01-14T14:22:49.911         0.16      -0.160
# 3  1547472169991  2019-01-14T14:22:49.991         0.24      -0.208
# 4  1547472170071  2019-01-14T14:22:50.071         0.32      -0.223
#
#    y-axis (g)  z-axis (g)
# 0       0.702      -0.276
# 1       0.710      -0.360
# 2       0.768      -0.392
# 3       0.817      -0.379
# 4       0.839      -0.403

# %%
list_of_files = list_data_files()
print("Available data files:", list_of_files)
# Out:
# Available data files: ['/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/ ...

# %%
# %%

"""
This module handles data processing for the barbell exercise tracking project.
Interactive development is supported - use Shift+Enter to run code blocks.
"""

import pandas as pd
from glob import glob

# --------------------------------------------------------------
# Read single CSV file
# --------------------------------------------------------------

def read_csv_file(file_path):
    """Read a CSV file from the data directory"""
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return None

# Example path structure (adjust according to your data location):
# Absolute path from project root
DATA_PATH = "data/raw/"  # This will be relative to where you run the notebook from

# You can also use this more robust path that works regardless of where you run from:
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.path.dirname(__file__), "../.."))
ABSOLUTE_DATA_PATH = os.path.join(PROJECT_ROOT, "data", "raw")

# Example usage with an actual file from your dataset:
EXAMPLE_FILE = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

def list_data_files():
    """List all CSV files in the raw data directory"""
    return glob(os.path.join(ABSOLUTE_DATA_PATH, '*.csv'))

def load_example_data():
    """Load an example CSV file from the raw data directory"""
    file_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
    return read_csv_file(file_path)

# file = load_example_data()
# file.head()

list_of_files = list_data_files()
print(list_of_files)
# --------------------------------------------------------------
# Extract features from filename
# --------------------------------------------------------------

# --------------------------------------------------------------
# Read all files
# --------------------------------------------------------------

# --------------------------------------------------------------
# Working with datetimes
# --------------------------------------------------------------

# --------------------------------------------------------------
# Turn into function
# --------------------------------------------------------------

# --------------------------------------------------------------
# Merging datasets
# --------------------------------------------------------------

# --------------------------------------------------------------
# Resample data (frequency conversion)
# --------------------------------------------------------------

# Accelerometer:    12.500HZ
# Gyroscope:        25.000Hz

# --------------------------------------------------------------
# Export dataset
# --------------------------------------------------------------

if __name__ == '__main__':
    # This code will run when executing the file directly
    # but won't run when importing the file
    files = list_data_files()
    print("Available data files:", files)

# For interactive development (Shift+Enter):
# Example usage:
# files = list_data_files()
# data = load_example_data()
# data.head()
# Out:
# ['/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-squat-heavy ...
# Available data files: ['/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/B-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.42.43.398_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-squat-heavy_MetaWear_2019-01-15T20.11.55.634_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-ohp-heavy_MetaWear_2019-01-14T14.49.46.484_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-heavy_MetaWear_2019-01-15T20.09.06.903_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-row-medium_MetaWear_2019-01-14T15.01.39.689_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-row-heavy_MetaWear_2019-01-14T15.06.50.281_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/D-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Accelerometer_12.500Hz_1.4.41.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/B-ohp-medium3-rpe9_MetaWear_2019-01-11T16.59.28.181_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-dead-medium_MetaWear_2019-01-15T20.26.26.347_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-bench-heavy_MetaWear_2019-01-14T14.51.27.130_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-ohp-medium2-rpe7_MetaWear_2019-01-11T16.57.30.113_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy2_MetaWear_2019-01-14T14.27.00.784_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-rest-sitting_MetaWear_2019-01-18T18.22.25.565_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/C-row-heavy_MetaWear_2019-01-14T15.05.36.986_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy2-rpe8_MetaWear_2019-01-11T16.10.08.270_C42732BE255C_Gyroscope_25.000Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-ohp-heavy2-rpe7_MetaWear_2019-01-11T16.41.24.439_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-medium_MetaWear_2019-01-18T18.21.29.033_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-row-medium_MetaWear_2019-01-18T18.30.48.777_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/E-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-squat-medium3-rpe7_MetaWear_2019-01-11T17.19.34.896_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-rest-standing_MetaWear_2019-01-18T18.25.39.382_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv', '/Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/ ...

# %%
filename = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'
features = extract_features_from_filename(filename)
print(features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/src/data/make_dataset.py:2
#       1 filename = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'
# ----> 2 features = extract_features_from_filename(filename)
#       3 print(features)
#
# NameError: name 'extract_features_from_filename' is not defined

# %%
def extract_features_from_filename(filename):
    """
    Extract features from a MetaWear data filename.
    Example filename: A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
    
    Returns:
        dict: Dictionary containing extracted features
    """
    # Remove .csv extension and split by underscores
    parts = filename.replace('.csv', '').split('_')
    
    # Extract exercise info (e.g., 'A-bench-heavy')
    exercise_info = parts[0].split('-')
    participant = exercise_info[0]  # e.g., 'A'
    exercise_name = exercise_info[1]  # e.g., 'bench'
    exercise_category = exercise_info[2].rstrip('123')  # e.g., 'heavy'
    # Option here to gain more features by creating reps, sets, etc.
    
    # Extract sensor info
    sensor_type = parts[4]  # e.g., 'Accelerometer'
    
    return {
        'participant': participant,
        'exercise_name': exercise_name,
        'exercise_category': exercise_category,
        'sensor_type': sensor_type
    }

def create_metadata_from_filename(filename):
    """
    Create a pandas DataFrame with metadata extracted from the filename.
    
    Args:
        filename (str): Name of the data file
        
    Returns:
        pd.DataFrame: Single-row DataFrame containing metadata
    """
    features = extract_features_from_filename(filename)
    return pd.DataFrame([features])

# Example usage in interactive mode:
filename = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'
features = extract_features_from_filename(filename)
print(features)
# Out:
# {'participant': 'A', 'exercise_name': 'bench', 'exercise_category': 'heavy', 'sensor_type': 'Accelerometer'}

# %%
test_files = [
    'A-bench-heavy1_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
    'B-squat-light2_MetaWear_2019-01-14T14.30.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv',
    'C-press-medium3_MetaWear_2019-01-14T14.40.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'
]

for test_file in test_files:
    print(f"\nProcessing: {test_file}")
    print(extract_features_from_filename(test_file))
# Out:
# Processing: A-bench-heavy1_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# {'participant': 'A', 'exercise_name': 'bench', 'exercise_category': 'heavy', 'sensor_type': 'Accelerometer'}
#
# Processing: B-squat-light2_MetaWear_2019-01-14T14.30.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# {'participant': 'B', 'exercise_name': 'squat', 'exercise_category': 'light', 'sensor_type': 'Accelerometer'}
#
# Processing: C-press-medium3_MetaWear_2019-01-14T14.40.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# {'participant': 'C', 'exercise_name': 'press', 'exercise_category': 'medium', 'sensor_type': 'Accelerometer'}

# %%
# --------------------------------------------------------------
# Create individual dataframes
# --------------------------------------------------------------
def create_dataframe_from_filename(filename) -> DataFrame:
    """
    Create a pandas DataFrame containing:
    - the data in the .csv file
    - the metadata extracted from the filename as new columns.
    
    Args:
        filename (str): Name of the data file
        
    Returns:
        pd.DataFrame: DataFrame containing data and metadata
    """
    data = read_csv_file(filename)
    features = extract_features_from_filename(filename)
    return pd.DataFrame([features])


# # Or create a DataFrame
metadata_df = create_dataframe_from_filename(EXAMPLE_FILE)
metadata_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/src/data/make_dataset.py:4
#       1 # --------------------------------------------------------------
#       2 # Create individual dataframes
#       3 # --------------------------------------------------------------
# ----> 4 def create_dataframe_from_filename(filename) -> DataFrame:
#       5     """
#       6     Create a pandas DataFrame containing:
#       7     - the data in the .csv file
#    (...)
#      14         pd.DataFrame: DataFrame containing data and metadata
#      15     """
#      16     data = read_csv_file(filename)
#
# NameError: name 'DataFrame' is not defined

# %%
# --------------------------------------------------------------
# Create individual dataframes
# --------------------------------------------------------------
def create_dataframe_from_filename(filename) -> pd.DataFrame:
    """
    Create a pandas DataFrame containing:
    - the data in the .csv file
    - the metadata extracted from the filename as new columns.
    
    Args:
        filename (str): Name of the data file
        
    Returns:
        pd.DataFrame: DataFrame containing data and metadata
    """
    data = read_csv_file(filename)
    features = extract_features_from_filename(filename)
    return pd.DataFrame([features])


# # Or create a DataFrame
metadata_df = create_dataframe_from_filename(EXAMPLE_FILE)
metadata_df.head()
# Out:
# Error reading A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv: [Errno 2] No such file or directory: 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'
#   participant exercise_name exercise_category    sensor_type
# 0           A         bench             heavy  Accelerometer

# %%
"""
This module handles data processing for the barbell exercise tracking project.
Interactive development is supported - use Shift+Enter to run code blocks.
"""

import pandas as pd
from glob import glob

# --------------------------------------------------------------
# Read single CSV file
# --------------------------------------------------------------

def read_csv_file(file_path):
    """Read a CSV file from the data directory"""
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return None

# Example path structure (adjust according to your data location):
# Absolute path from project root
DATA_PATH = "data/raw/"  # This will be relative to where you run the notebook from

# You can also use this more robust path that works regardless of where you run from:
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.path.dirname(__file__), "../.."))
ABSOLUTE_DATA_PATH = os.path.join(PROJECT_ROOT, "data", "raw")

# Example usage with an actual file from your dataset:
EXAMPLE_FILE = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

def list_data_files():
    """List all CSV files in the raw data directory"""
    return glob(os.path.join(ABSOLUTE_DATA_PATH, '*.csv'))

def load_example_data():
    """Load an example CSV file from the raw data directory"""
    file_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
    return read_csv_file(file_path)

# --------------------------------------------------------------
# Extract features from filename
# --------------------------------------------------------------

def extract_features_from_filename(filename) -> dict:
    """
    Extract features from a MetaWear data filename.
    Example filename: A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
    
    Returns:
        dict: Dictionary containing extracted features
    """
    # Remove .csv extension and split by underscores
    parts = filename.replace('.csv', '').split('_')
    
    # Extract exercise info (e.g., 'A-bench-heavy')
    exercise_info = parts[0].split('-')
    participant = exercise_info[0]  # e.g., 'A'
    exercise_name = exercise_info[1]  # e.g., 'bench'
    exercise_category = exercise_info[2].rstrip('123')  # e.g., 'heavy'
    # Option here to gain more features by creating reps, sets, etc.
    
    # Extract sensor info
    sensor_type = parts[4]  # e.g., 'Accelerometer'
    
    return {
        'participant': participant,
        'exercise_name': exercise_name,
        'exercise_category': exercise_category,
        'sensor_type': sensor_type
    }

# Example usage in interactive mode:
# filename = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'
# features = extract_features_from_filename(filename)
# print(features)


# --------------------------------------------------------------
# Create individual dataframes
# --------------------------------------------------------------
def create_dataframe_from_filename(filename) -> pd.DataFrame:
    """
    Create a pandas DataFrame containing:
    - the data in the .csv file
    - the metadata extracted from the filename as new columns.
    
    Args:
        filename (str): Name of the data file
        
    Returns:
        pd.DataFrame: DataFrame containing data and metadata
    """
    data = read_csv_file(filename)
    features = extract_features_from_filename(filename)
    return pd.DataFrame([features])


# # Or create a DataFrame
metadata_df = create_dataframe_from_filename(EXAMPLE_FILE)
metadata_df.head()
# Out:
# Error reading A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv: [Errno 2] No such file or directory: 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'
#   participant exercise_name exercise_category    sensor_type
# 0           A         bench             heavy  Accelerometer

# %%
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")
# Out:
# participant: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds
# exercise_name: project
# exercise_category: template/data/raw/A
# sensor_type: Accelerometer

# %%
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")
# Out:
# participant: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds
# exercise_name: project
# exercise_category: template/data/raw/A
# sensor_type: Accelerometer

# %%
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")
# Out:
# participant: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds
# exercise_name: project
# exercise_category: template/data/raw/A
# sensor_type: Accelerometer

# %%
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")
# Out:
# participant: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds
# exercise_name: project
# exercise_category: template/data/raw/A
# sensor_type: Accelerometer

# %%
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")
# Out:
# participant: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds
# exercise_name: project
# exercise_category: template/data/raw/A
# sensor_type: Accelerometer

# %%
"""
This module handles data processing for the barbell exercise tracking project.
Interactive development is supported - use Shift+Enter to run code blocks.
"""

import pandas as pd
from glob import glob
import os

# --------------------------------------------------------------
# Read single CSV file
# --------------------------------------------------------------

def read_csv_file(file_path):
    """Read a CSV file from the data directory"""
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return None

# Example path structure (adjust according to your data location):
# Absolute path from project root
DATA_PATH = "data/raw/"  # This will be relative to where you run the notebook from

# You can also use this more robust path that works regardless of where you run from:
PROJECT_ROOT = os.path.abspath(os.path.join(os.path.dirname(__file__), "../.."))
ABSOLUTE_DATA_PATH = os.path.join(PROJECT_ROOT, "data", "raw")

# Example usage with an actual file from your dataset:
EXAMPLE_FILE = 'A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv'

def list_data_files():
    """List all CSV files in the raw data directory"""
    return glob(os.path.join(ABSOLUTE_DATA_PATH, '*.csv'))

def load_example_data():
    """Load an example CSV file from the raw data directory"""
    file_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
    return read_csv_file(file_path)

# --------------------------------------------------------------
# Extract features from filename
# --------------------------------------------------------------

def extract_features_from_filename(file_path: str) -> dict:
    """
    Extract features from a MetaWear data file path.
    Example path: /path/to/data/A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
    
    Args:
        file_path (str): Full path to the data file
    
    Returns:
        dict: Dictionary containing extracted features
    """
    # Extract just the filename from the path
    filename = os.path.basename(file_path)
    
    # Remove .csv extension and split by underscores
    parts = filename.replace('.csv', '').split('_')
    
    # Extract exercise info (e.g., 'A-bench-heavy')
    exercise_info = parts[0].split('-')
    participant = exercise_info[0]  # e.g., 'A'
    exercise_name = exercise_info[1]  # e.g., 'bench'
    exercise_category = exercise_info[2].rstrip('123')  # e.g., 'heavy'
    # Option here to gain more features by creating reps, sets, etc.
    
    # Extract sensor info
    sensor_type = parts[4]  # e.g., 'Accelerometer'
    
    return {
        'participant': participant,
        'exercise_name': exercise_name,
        'exercise_category': exercise_category,
        'sensor_type': sensor_type
    }

# Example usage in interactive mode:
# Test with our example file using full path
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")
# Out:
# participant: A
# exercise_name: bench
# exercise_category: heavy
# sensor_type: Accelerometer

# %%
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")# Test with our example file using full path
    example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
    print(f"Full path: {example_path}")
    print(f"Extracted filename: {os.path.basename(example_path)}\n")
    
    features = extract_features_from_filename(example_path)
    
    # View the extracted features
    for key, value in features.items():
        print(f"{key}: {value}")
# Out:
# participant: A
# Full path: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# Extracted filename: A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
#
# participant: A
# exercise_name: bench
# exercise_category: heavy
# sensor_type: Accelerometer
# exercise_name: bench
# Full path: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# Extracted filename: A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
#
# participant: A
# exercise_name: bench
# exercise_category: heavy
# sensor_type: Accelerometer
# exercise_category: heavy
# Full path: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# Extracted filename: A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
#
# participant: A
# exercise_name: bench
# exercise_category: heavy
# sensor_type: Accelerometer
# sensor_type: Accelerometer
# Full path: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# Extracted filename: A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
#
# participant: A
# exercise_name: bench
# exercise_category: heavy
# sensor_type: Accelerometer

# %%
# Test with our example file using full path
example_path = os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE)
print(f"Full path: {example_path}")
print(f"Extracted filename: {os.path.basename(example_path)}\n")

features = extract_features_from_filename(example_path)

# View the extracted features
for key, value in features.items():
    print(f"{key}: {value}")
# Out:
# Full path: /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/data/raw/A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
# Extracted filename: A-bench-heavy_MetaWear_2019-01-14T14.22.49.165_C42732BE255C_Accelerometer_12.500Hz_1.4.4.csv
#
# participant: A
# exercise_name: bench
# exercise_category: heavy
# sensor_type: Accelerometer

# %%
df = create_dataframe_from_file(os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE))
print("\nDataFrame with features:")
print(df.head())
print("\nAll columns:")
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/samuelklettnavarro/Dropbox/PY4E/repos/ds-project-template/src/data/make_dataset.py:1
# ----> 1 df = create_dataframe_from_file(os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE))
#       2 print("\nDataFrame with features:")
#       3 print(df.head())
#
# NameError: name 'create_dataframe_from_file' is not defined

# %%
def create_dataframe_from_file(file_path: str) -> pd.DataFrame:
    """
    Create a pandas DataFrame containing:
    - the data in the .csv file
    - the metadata extracted from the filename as new columns.
    
    Args:
        file_path (str): Full path to the data file
        
    Returns:
        pd.DataFrame: DataFrame containing data and metadata
    """
    # Read the CSV data
    df = read_csv_file(file_path)
    
    # Extract features from filename
    features = extract_features_from_filename(file_path)
    
    # Add features as new columns
    for feature_name, feature_value in features.items():
        df[feature_name] = feature_value
    
    return df

# Example usage:
df = create_dataframe_from_file(os.path.join(ABSOLUTE_DATA_PATH, EXAMPLE_FILE))
print("\nDataFrame with features:")
print(df.head())
print("\nAll columns:")
print(df.columns.tolist())
# Out:
# DataFrame with features:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547472169751  2019-01-14T14:22:49.751         0.00      -0.147
# 1  1547472169831  2019-01-14T14:22:49.831         0.08      -0.120
# 2  1547472169911  2019-01-14T14:22:49.911         0.16      -0.160
# 3  1547472169991  2019-01-14T14:22:49.991         0.24      -0.208
# 4  1547472170071  2019-01-14T14:22:50.071         0.32      -0.223
#
#    y-axis (g)  z-axis (g) participant exercise_name exercise_category  \
# 0       0.702      -0.276           A         bench             heavy
# 1       0.710      -0.360           A         bench             heavy
# 2       0.768      -0.392           A         bench             heavy
# 3       0.817      -0.379           A         bench             heavy
# 4       0.839      -0.403           A         bench             heavy
#
#      sensor_type
# 0  Accelerometer
# 1  Accelerometer
# 2  Accelerometer
# 3  Accelerometer
# 4  Accelerometer
#
# All columns:
# ['epoch (ms)', 'time (01:00)', 'elapsed (s)', 'x-axis (g)', 'y-axis (g)', 'z-axis (g)', 'participant', 'exercise_name', 'exercise_category', 'sensor_type']

# %%
def create_sensor_dataframes_from_files(filelist: list) -> tuple[pd.DataFrame, pd.DataFrame]:
    """
    Create two pandas DataFrames, one for accelerometer and one for gyroscope data,
    containing the data from all files with their respective metadata.
    A 'set' counter is added to each dataframe starting from 1.
    
    Args:
        filelist (list): List of file paths to process
        
    Returns:
        tuple[pd.DataFrame, pd.DataFrame]: Tuple containing (accelerometer_df, gyroscope_df)
    """
    # Initialize empty dataframes for each sensor type
    acce_df = pd.DataFrame()
    gyro_df = pd.DataFrame()
    
    # Initialize set counters
    acce_set_counter = 1
    gyro_set_counter = 1
    
    # Process each file
    for file_path in filelist:
        # Create dataframe with features
        df = create_dataframe_from_file(file_path)
        
        # Add to respective dataframe based on sensor type
        if df['sensor_type'].iloc[0] == 'Accelerometer':
            df['set'] = acce_set_counter
            acce_df = pd.concat([acce_df, df], ignore_index=True)
            acce_set_counter += 1
        elif df['sensor_type'].iloc[0] == 'Gyroscope':
            df['set'] = gyro_set_counter
            gyro_df = pd.concat([gyro_df, df], ignore_index=True)
            gyro_set_counter += 1
    
    return acce_df, gyro_df

# Get list of files
data_files = glob(os.path.join(ABSOLUTE_DATA_PATH, "*.csv"))
print(f"Found {len(data_files)} files")

# Create sensor dataframes
acc_df, gyro_df = create_sensor_dataframes_from_files(data_files)

print("\nAccelerometer DataFrame:")
print(f"- Shape: {acc_df.shape}")
print(f"- Number of unique sets: {acc_df['set'].nunique()}")
print(f"- Columns: {acc_df.columns.tolist()}")
print("\nFirst few rows:")
print(acc_df.head())

print("\nGyroscope DataFrame:")
print(f"- Shape: {gyro_df.shape}")
print(f"- Number of unique sets: {gyro_df['set'].nunique()}")
print(f"- Columns: {gyro_df.columns.tolist()}")
print("\nFirst few rows:")
print(gyro_df.head())
# Out:
# Found 187 files
#
# Accelerometer DataFrame:
# - Shape: (23578, 11)
# - Number of unique sets: 94
# - Columns: ['epoch (ms)', 'time (01:00)', 'elapsed (s)', 'x-axis (g)', 'y-axis (g)', 'z-axis (g)', 'participant', 'exercise_name', 'exercise_category', 'sensor_type', 'set']
#
# First few rows:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (g)  \
# 0  1547221363566  2019-01-11T16:42:43.566         0.00      -0.136
# 1  1547221363646  2019-01-11T16:42:43.646         0.08      -0.143
# 2  1547221363726  2019-01-11T16:42:43.726         0.16      -0.187
# 3  1547221363806  2019-01-11T16:42:43.806         0.24      -0.152
# 4  1547221363886  2019-01-11T16:42:43.886         0.32      -0.143
#
#    y-axis (g)  z-axis (g) participant exercise_name exercise_category  \
# 0       0.986      -0.053           B           ohp             heavy
# 1       0.977      -0.053           B           ohp             heavy
# 2       0.935       0.039           B           ohp             heavy
# 3       0.958      -0.075           B           ohp             heavy
# 4       0.944       0.010           B           ohp             heavy
#
#      sensor_type  set
# 0  Accelerometer    1
# 1  Accelerometer    1
# 2  Accelerometer    1
# 3  Accelerometer    1
# 4  Accelerometer    1
#
# Gyroscope DataFrame:
# - Shape: (47218, 11)
# - Number of unique sets: 93
# - Columns: ['epoch (ms)', 'time (01:00)', 'elapsed (s)', 'x-axis (deg/s)', 'y-axis (deg/s)', 'z-axis (deg/s)', 'participant', 'exercise_name', 'exercise_category', 'sensor_type', 'set']
#
# First few rows:
#       epoch (ms)             time (01:00)  elapsed (s)  x-axis (deg/s)  \
# 0  1547579347087  2019-01-15T20:09:07.087         0.00           4.451
# 1  1547579347127  2019-01-15T20:09:07.127         0.04           3.902
# 2  1547579347167  2019-01-15T20:09:07.167         0.08          -1.159
# 3  1547579347207  2019-01-15T20:09:07.207         0.12          -5.732
# 4  1547579347247  2019-01-15T20:09:07.247         0.16           2.195
#
#    y-axis (deg/s)  z-axis (deg/s) participant exercise_name exercise_category  \
# 0          -1.159          -0.061           A         squat             heavy
# 1          -1.951          -1.220           A         squat             heavy
# 2          -1.585          -2.866           A         squat             heavy
# 3          -1.646           1.037           A         squat             heavy
# 4          -4.024           0.061           A         squat             heavy
#
#   sensor_type  set
# 0   Gyroscope    1
# 1   Gyroscope    1
# 2   Gyroscope    1
# 3   Gyroscope    1
# 4   Gyroscope    1

# %%
acc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23578 entries, 0 to 23577
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   epoch (ms)         23578 non-null  int64
#  1   time (01:00)       23578 non-null  object
#  2   elapsed (s)        23578 non-null  float64
#  3   x-axis (g)         23578 non-null  float64
#  4   y-axis (g)         23578 non-null  float64
#  5   z-axis (g)         23578 non-null  float64
#  6   participant        23578 non-null  object
#  7   exercise_name      23578 non-null  object
#  8   exercise_category  23578 non-null  object
#  9   sensor_type        23578 non-null  object
#  10  set                23578 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 2.0+ MB
